# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp
import itertools
from astropy.io import fits
import scipy
import pymaster as nmt
from planck_util import *

# %%
ps = PlanckSpectra()
f1, f2 = '143', '143'
Cb = ps.compute(f1, f2, '2', '1')
# Out:
# /home/zequnl/anaconda3/lib/python3.6/site-packages/healpy/fitsfunc.py:371: UserWarning: No INDXSCHM keyword in header file : assume IMPLICIT
#   warnings.warn("No INDXSCHM keyword in header file : " "assume {}".format(schm))

# %%
bt, bte, be = ps.get_Bbl_from_last_workspace()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-703127d06a74> in <module>
# ----> 1 bt, bte, be = ps.get_Bbl_from_last_workspace()
#
# ~/Installs/PSpipe/project/Planck/notebooks/planck_util.py in get_Bbl_from_last_workspace(self)
#     192             Bbl_TT[:,i] = w0.decouple_cell(w0.couple_cell([delt]))
#     193             Bbl_TE[:,i], _ = w1.decouple_cell(w1.couple_cell([delt, delt]))
# --> 194             Bbl_EE[:,i], _, _, _ = w2.decouple_cell(w2.couple_cell([delt, delt, delt, delt]))
#     195
#     196         for i in range(nb):
#
# ~/anaconda3/lib/python3.6/site-packages/pymaster/workspaces.py in couple_cell(self, cl_in)
#      85         if (len(cl_in) != self.wsp.ncls) or (len(cl_in[0]) < self.wsp.lmax + 1):
#      86             raise ValueError("Input power spectrum has wrong shape")
# ---> 87         cl1d = lib.couple_cell_py(self.wsp, cl_in, self.wsp.ncls * (self.wsp.lmax + 1))
#      88         clout = np.reshape(cl1d, [self.wsp.ncls, self.wsp.lmax + 1])
#      89         return clout
#
# KeyboardInterrupt:

# %%
# Out:
# (0, 50)

# %%
fig, axes = plt.subplots(3,1,figsize=(12,14))

for spec, ax in zip(['TT', 'TE', 'EE'], axes):
    lmin_,lmax_,l_ref,cl_ref,error_ref=np.loadtxt('planck_spectra/spectra_' + f'{spec}_{f1}x{f2}' + '.dat',unpack=True)
    dl_ref_fac = l_ref*(l_ref+1)/(2*np.pi)
  
    ax.errorbar(l_ref,cl_ref*dl_ref_fac,
                error_ref*dl_ref_fac,
                fmt='.',label='%s'%f'{spec}_{f1}x{f2}', alpha=0.5)

    ax.plot(ps.lb, Cb[spec] * 1e12 ,'r.',label=r"NaMaster", alpha=0.5)

# %%
fig, axes = plt.subplots(3,1,figsize=(12,14))

for spec, ax in zip(['TT', 'TE', 'EE'], axes):
    lmin_,lmax_,l_ref,cl_ref,error_ref=np.loadtxt('planck_spectra/spectra_' + f'{spec}_{f1}x{f2}' + '.dat',unpack=True)
    dl_ref_fac = l_ref*(l_ref+1)/(2*np.pi)

    dl = np.interp(x=l_ref, xp=ps.lb, fp=Cb[spec] * 1e12) 
    ax.plot(l_ref, (dl - (cl_ref * dl_ref_fac)) / (error_ref * dl_ref_fac), 
            'k.-', label=spec)
    ax.axhline(0, color='red', alpha=0.3)
#     ax.set_ylim(-3,3)
    ax.legend()
    
axes[0].set_title(f'{f1}x{f2}')

plt.tight_layout()
